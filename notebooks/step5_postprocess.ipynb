# %%
"""Transform the predictions from the normalized data back to the original CTA data space using the transforms from data.py. This is necessary because the predictions are made on normalized data, and we want to visualize them in the original CTA space."""

import sys
sys.path.append('..')

from src.processing import transform_all


if __name__ == "__main__":
    
    root_pred = "../nnUNet_raw/Predictions_val"
    root_ncct = "../nnUNet_raw/Dataset/imagesTr"
    root_out = "../nnUNet_raw/Predictions_val_small"
    models = ["cknn", "knn"]
    
    for model in models:
        root_pred_model = f"{root_pred}/images_{model}/"
        root_out_model = f"{root_out}/images_{model}/"
        
        transform_all(root_pred_model, root_ncct, root_out_model, [7, 10, 12])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 import sys
#       4 sys.path.append('..')
#       5
# ----> 6 from src.processing import transform_all
#       7
#       8
#       9 if __name__ == "__main__":
#
# File ~/aipek_task_2026/notebooks/../src/processing.py:3
#       1 import torch
# ----> 3 from src.data import NiiPoint
#       6 class CONSTANTS:
#       7     BACK = 0    # Background
#
# File ~/aipek_task_2026/notebooks/../src/data.py:17
#      15 import os
#      16 import shutil
# ---> 17 from src.plots import plot_slices
#      20 def _make_contiguous(x):
#      21     return x.contiguous()
#
# File ~/aipek_task_2026/notebooks/../src/plots.py:11
#       8 from pathlib import Path
#       9 from typing import Any
# ---> 11 from src.data import plot_slices
#      13 def plot_from_path(path, slices, thicknesses=None, axes=None, **kwargs):
#      14     from src.data import NiiPoint
#
# ImportError: cannot import name 'plot_slices' from partially initialized module 'src.data' (most likely due to a circular import) (/home/emastr/aipek_task_2026/notebooks/../src/data.py)
